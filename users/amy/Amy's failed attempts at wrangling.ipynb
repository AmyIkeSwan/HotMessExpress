# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %%
raw = pd.read_csv('C:/Users/amysw/OneDrive - Southern Careers Institute/DSO110 FinalGroupProject/data/f2fMerged_raw.csv')

# %% [raw]
# raw.columns

# %%
raw.columns
# Out:
# Index(['UID', 'Section', 'Group', 'Sum_Introversion', 'Sum_Extraversion',
#        'TBL1_iRAT', 'TBL2_iRAT', 'TBL3_iRAT', 'TBL4_iRAT', 'TBL1_tRAT',
#        'TBL2_tRAT', 'TBL3_tRAT', 'TBL4_tRAT', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38'],
#       dtype='object')

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UID               624 non-null    object
#  1   Section           624 non-null    object
#  2   Group             624 non-null    object
#  3   Sum_Introversion  624 non-null    object
#  4   Sum_Extraversion  624 non-null    object
#  5   TBL1_iRAT         625 non-null    object
#  6   TBL2_iRAT         625 non-null    object
#  7   TBL3_iRAT         625 non-null    object
#  8   TBL4_iRAT         625 non-null    object
#  9   TBL1_tRAT         625 non-null    object
#  10  TBL2_tRAT         625 non-null    object
#  11  TBL3_tRAT         625 non-null    object
#  12  TBL4_tRAT         625 non-null    object
#  13  Unnamed: 13       624 non-null    object
#  14  Unnamed: 14       625 non-null    object
#  15  Unnamed: 15       624 non-null    object
# ...

# %%
import numpy as np

# %%
raw1 = raw['Section'].str.split('/', expand = True)

# %%
raw1.head()
# Out:
#           0
# 0   Section
# 1  F2F_2021
# 2  F2F_2021
# 3  F2F_2021
# 4  F2F_2021

# %%
raw2 = pd.concat([raw, raw1], axis =1)

# %%
raw2.head()
# Out:
#      UID   Section  Group  Sum_Introversion  Sum_Extraversion  \
# 0     ID   Section  Group  Sum_Introversion  Sum_Extraversion
# 1  10267  F2F_2021     24                24                11
# 2  23143  F2F_2021      8                20                13
# 3  23144  F2F_2021      8              9999              9999
# 4  23145  F2F_2021      5                18                18
#
#                                            TBL1_iRAT  \
# 0  Module 1: iRAT -- Requires Respondus LockDown ...
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#                                            TBL2_iRAT  \
# 0  Module 2: iRAT - Requires Respondus LockDown B...
# 1                                                  2
# 2                                                  2
# ...

# %%
raw2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 625 entries, 0 to 624
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UID               624 non-null    object
#  1   Section           624 non-null    object
#  2   Group             624 non-null    object
#  3   Sum_Introversion  624 non-null    object
#  4   Sum_Extraversion  624 non-null    object
#  5   TBL1_iRAT         625 non-null    object
#  6   TBL2_iRAT         625 non-null    object
#  7   TBL3_iRAT         625 non-null    object
#  8   TBL4_iRAT         625 non-null    object
#  9   TBL1_tRAT         625 non-null    object
#  10  TBL2_tRAT         625 non-null    object
#  11  TBL3_tRAT         625 non-null    object
#  12  TBL4_tRAT         625 non-null    object
#  13  Unnamed: 13       624 non-null    object
#  14  Unnamed: 14       625 non-null    object
#  15  Unnamed: 15       624 non-null    object
# ...

# %%
def Section(series):
    if series == "F2F_2019":
        return 2019
    if series == "F2F_2020":
        return 2020
    if series == "F2F_2021":
        return 2021

# %%
raw1['2019', '2020', '2021'] = raw1 ['Section'].apply(Section)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-afe321cfa262> in <module>
# ----> 1 raw1['2019', '2020', '2021'] = raw1 ['Section'].apply(Section)
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\tools\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
#     353                     raise KeyError(key) from err
# --> 354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#     356
#
# ...
