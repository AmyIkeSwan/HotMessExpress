# %%
## Import packages
import numpy as np
import pandas as pd

# %%
## Import CSV data
f2f_teams = pd.read_csv("f2fMerged_raw.csv")

# %%
## View Data
f2f_teams
# Out:
#        UID   Section  Group  Sum_Introversion  Sum_Extraversion  \
# 0       ID   Section  Group  Sum_Introversion  Sum_Extraversion
# 1    10267  F2F_2021     24                24                11
# 2    23143  F2F_2021      8                20                13
# 3    23144  F2F_2021      8              9999              9999
# 4    23145  F2F_2021      5                18                18
# ..     ...       ...    ...               ...               ...
# 620  19143  F2F_2019      3                29                 5
# 621  19144  F2F_2019      8                18                17
# 622  19145  F2F_2019     10                29                 6
# 623  19153  F2F_2019     15                15                18
# 624    NaN       NaN    NaN               NaN               NaN
#
#                                              TBL1_iRAT  \
# 0    Module 1: iRAT -- Requires Respondus LockDown ...
# 1                                                    3
# ...

# %%
## Begin the process of attempting to break up data according to the Section column
f2f_section = pd.get_dummies(f2f_teams['Section'])

# %%
f2f_sectioned = pd.concat([f2f_teams, f2f_section], axis=1)

# %%
#View to confirm that the new columns are in the dataset and able to be worked with

f2f_sectioned
# Out:
#        UID   Section  Group  Sum_Introversion  Sum_Extraversion  \
# 0       ID   Section  Group  Sum_Introversion  Sum_Extraversion
# 1    10267  F2F_2021     24                24                11
# 2    23143  F2F_2021      8                20                13
# 3    23144  F2F_2021      8              9999              9999
# 4    23145  F2F_2021      5                18                18
# ..     ...       ...    ...               ...               ...
# 620  19143  F2F_2019      3                29                 5
# 621  19144  F2F_2019      8                18                17
# 622  19145  F2F_2019     10                29                 6
# 623  19153  F2F_2019     15                15                18
# 624    NaN       NaN    NaN               NaN               NaN
#
#                                              TBL1_iRAT  \
# 0    Module 1: iRAT -- Requires Respondus LockDown ...
# 1                                                    3
# ...
