# %%
## Final Project - Demographics in Python
## 2022-04-05

# %%
## load packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## import f2fmerged dataset
f2fmerged = pd.read_csv("C:/Users/Brandy/Documents/GitHub/HotMessExpress/users/brandy/2_DataAnalyses/f2fMerged_clean.csv")

f2fmerged
# Out:
#        UID  Cohort  Group  Sum_Introversion  Sum_Extroversion  TBL1_iRAT  \
# 0    18893    2019      1                14                22          2
# 1    18937    2019      1                13                21          5
# 2    18960    2019      1                19                15          4
# 3    18972    2019      1                 5                30          4
# 4    18981    2019      1                20                14          2
# ..     ...     ...    ...               ...               ...        ...
# 607  23188    2021     25                21                13          1
# 608  23283    2021     25                10                26          3
# 609  23304    2021     25                13                21          3
# 610  23343    2021     25                15                18          0
# 611  23399    2021     25                 9                27          4
#
#      TBL2_iRAT  TBL3_iRAT  TBL1_tRAT  TBL2_tRAT  TBL3_tRAT  TBL1_RATdiff  \
# 0            2          3         15         13         14             9
# 1            0          3         15         13         14             0
# 2            4          2         15         13         14             3
# 3            4          1         15         13         14             3
# 4            4          3         15         13         14             9
# ..         ...        ...        ...        ...        ...           ...
# 607          1          1         15         11         15            12
# 608          2          4         15         11         15             6
# 609          2          2         15         11         15             6
# 610          3          1         15         11         15            15
# 611          3          4         15         11         15             3
#
#      TBL2_RATdiff  TBL3_RATdiff
# 0               7             5
# 1              13             5
# 2               1             8
# 3               1            11
# 4               1             5
# ..            ...           ...
# 607             8            12
# 608             5             3
# 609             5             9
# 610             2            12
# 611             2             3
#
# [612 rows x 14 columns]

# %%
## import f2fmerged dataset
f2fTeamRatings = pd.read_csv("C:/Users/Brandy/Documents/GitHub/HotMessExpress/users/brandy/2_DataAnalyses/f2fTeamRatings_TBL1_TBL3_clean.csv")

f2fTeamRatings
# Out:
#     TeamUID  Mean_Introversion  Mean_Extroversion  Cohort  Group  \
# 0    201901          15.888889          18.222222    2019      1
# 1    201902          18.375000          16.375000    2019      2
# 2    201903          18.750000          15.500000    2019      3
# 3    201904          16.000000          18.888889    2019      4
# 4    201905          17.222222          17.333333    2019      5
# ..      ...                ...                ...     ...    ...
# 70   202121          21.833333          12.833333    2021     21
# 71   202122          18.428571          16.857143    2021     22
# 72   202123          18.428571          16.000000    2021     23
# 73   202124          19.428571          16.000000    2021     24
# 74   202125          12.285714          22.571429    2021     25
#
#     TBL1_TBL3_diff  TBL1_TBL3_1_diff  TBL1_TBL3_2_diff  TBL1_TBL3_3_diff  \
# 0                4                 0                 1                 1
# 1                2                 1                 0                 0
# 2                2                 0                 0                 0
# 3                5                 0                 1                 2
# 4                4                 1                 1                 1
# ..             ...               ...               ...               ...
# 70               2                 0                 0                 1
# 71               2                 0                 0                 2
# 72               2                 1                 0                 0
# 73               4                 0                 0                 2
# 74               3                 0                 0                 1
#
#     TBL1_TBL3_4_diff  ...  TBL2_2_Conflict  TBL2_3_Roles  TBL2_4_DecisionMkg  \
# 0                  1  ...                4             2                   4
# 1                  0  ...                4             2                   4
# 2                  1  ...                4             4                   4
# 3                  0  ...                4             2                   3
# 4                  1  ...                4             4                   4
# ..               ...  ...              ...           ...                 ...
# 70                 0  ...                4             3                   4
# 71                 0  ...                4             2                   3
# 72                 0  ...                4             4                   4
# 73                 1  ...                4             4                   3
# 74                 1  ...                4             3                   4
#
#     TBL2_5_Planning  TBL3_TeamRating  TBL3_1_Engagement  TBL3_2_Conflict  \
# 0                 3               18                  4                4
# 1                 3               17                  4                4
# 2                 4               20                  4                4
# 3                 4               19                  4                4
# 4                 4               19                  4                4
# ..              ...              ...                ...              ...
# 70                4               20                  4                4
# 71                2               19                  4                4
# 72                4               19                  4                4
# 73                2               20                  4                4
# 74                3               18                  4                4
#
#     TBL3_3_Roles  TBL3_4_DecisionMkg  TBL3_5_Planning
# 0              3                   4                3
# 1              3                   3                3
# 2              4                   4                4
# 3              4                   3                4
# 4              4                   4                3
# ..           ...                 ...              ...
# 70             4                   4                4
# 71             4                   4                3
# 72             4                   4                3
# 73             4                   4                4
# 74             3                   4                3
#
# [75 rows x 29 columns]

# %%
## scatterplot of Introversion and Extroversion by cohort
### using pandas
Plot=f2fmerged.plot.scatter(x='Sum_Introversion', y='Sum_Extroversion', c='Cohort')
Plot.set_title('Self-Ratings for Introversion and Extroversion by Cohort')
Plot.set_xlabel('Introversion')
Plot.set_ylabel('Extroversion')

# %%
## scatterplot of Introversion and Extroversion by cohort
### using pyplot
groups = f2fmerged.groupby('Cohort')
for name, group in groups:
    plt.plot(group.Sum_Introversion, group.Sum_Extroversion, marker='o', linestyle='', markersize=3, label=name)
    plt.legend()

# %%
## scatterplot of Introversion and Extroversion by cohort
### using pyplot
plt.figure(figsize=(8,8))
sp_names = ['2019', '2020', '2021']
scatter = plt.scatter(f2fmerged.Sum_Introversion, 
                      f2fmerged.Sum_Extroversion, 
                      s=150,
                      c=f2fmerged.Cohort.astype('category').cat.codes)
plt.xlabel("Introversion Score", size=14)
plt.ylabel("Extroversion Score", size=14)
plt.legend(handles=scatter.legend_elements()[0],
           labels=sp_names, 
           title="Cohort")
plt.savefig("Self-Rated Introversion and Extroversion Scores by Cohort.png",
          format='png', dpi=150)

# %%
## scatterplot of Introversion and Extroversion by cohort
### using seaborn
sns.relplot(
data=f2fmerged, x="Sum_Introversion", y="Sum_Extroversion",
col="Cohort", style="Cohort",
kind="scatter")

# %%
## scatterplot of Introversion and Extroversion by cohort
f2fmerged['Sum_Introversion'].corr(f2fmerged['Sum_Extroversion'])
# Out:
# -0.9876526383340045
